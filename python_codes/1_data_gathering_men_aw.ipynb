# %% [markdown]
# # Web scraping to gather data: Men's AW Collection

# %% [markdown]
# > - Using the smallable website, men's and women's products will be scraped to prepare for creating a clothing and accessories recommendation.

# %%
# try to webscrap smallable
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from time import sleep
import random

# %%
# men's aw collection
m_aw_pages = range(1,13)

# %%
m_aw = f"https://www.smallable.com/en/fashion/adult/man?_collection=autumn-winter-collection"

# %%
# dataframe where all results will be stored
mens_aw = pd.DataFrame()

# iteration for webscrapping multiple pages
for page in m_aw_pages: #change pages on the link
    r = requests.get(f"https://www.smallable.com/en/fashion/adult/man?_collection=autumn-winter-collection&_page={page}")
    print(f'Response for page {page} :', r.status_code)
    soup = BeautifulSoup(r.content, 'html.parser')
    
    #empty lists
    link = []
    img = []
    tags = []
    brand = []
    product_color = []
    price_euro = []

    #scrapping infos from site
    for i in soup.find_all('a', attrs={"class": "ProductCard_content__fBfLV"}):
        link.append(i.get("href")) #link to product
        img.append(i.select('img')[1].get("src")) # photo link
        tags.append(i.find("div", attrs = {"class" : "ProductTags_container__3cc_M"}).get_text(strip = True, separator = "|"))

    for i in soup.find_all('ul', attrs={"class": "ProductCard_attr__2e2YT"}):
        brand.append(i.select("li")[0].get_text(strip = True)) #brand name
        product_color.append(i.select("li")[1].get_text(strip = True)) #product | color
        price_euro.append(i.select("li")[2].get_text(strip = True, separator = "|")) #price
    
    new_df = pd.DataFrame(list(zip(link, img, tags, brand, product_color, price_euro)),columns=("link", "img", "tags", "brand", "product_color", "price_euro"))
    # store everything in the previously prepared df and concatenate new results from new webpages
    mens_aw = pd.concat([mens_aw, new_df])
    
    wait_time = random.randint(2,7)
    print("I will sleep for " + str(wait_time) + " seconds.")
    sleep(wait_time) #Script will be stopped for a period of time ranging from 2 to 7 seconds
# Out:
# Response for page 1 : 200
# I will sleep for 7 seconds.
# Response for page 2 : 200
# I will sleep for 3 seconds.
# Response for page 3 : 200
# I will sleep for 5 seconds.
# Response for page 4 : 200
# I will sleep for 7 seconds.
# Response for page 5 : 200
# I will sleep for 7 seconds.
# Response for page 6 : 200
# I will sleep for 6 seconds.
# Response for page 7 : 200
# I will sleep for 2 seconds.
# Response for page 8 : 200
# I will sleep for 6 seconds.
# Response for page 9 : 200
# I will sleep for 4 seconds.
# Response for page 10 : 200
# I will sleep for 7 seconds.
# Response for page 11 : 200
# I will sleep for 4 seconds.
# Response for page 12 : 200
# I will sleep for 6 seconds.

# %%
mens_aw.to_csv('mens_aw.csv', index=False)

# %%
mens_aw.duplicated().sum()
# Out:
# 0

# %%
mens_aw
# Out:
#                                                  link
# 0   /en/product/hoodie-venice-address-grey-deux-ex...  \
# 1   /en/product/lionel-sunglasses-green-komono-313851
# 2   /en/product/set-2-paires-chaussettes-collectio...
# 3   /en/product/hoodie-essential-black-the-north-f...
# 4   /en/product/hoodie-essential-heather-grey-the-...
# ..                                                ...
# 21  /en/product/sue-sunglasses-adult-collection-gr...
# 22  /en/product/chase-t-shirt-navy-blue-carhartt-2...
# 23  /en/product/mohave-plain-bag-green-element-213741
# 24  /en/product/merino-wool-mittens-adult-collecti...
# 25  /en/product/le-vrai-3-0-claude-waterproof-wind...
#
#                                                   img           tags
# 0   https://static.smallable.com/1731880-648x648q8...            New  \
# 1   https://static.smallable.com/1678544-648x648q8...  New|Greenable
# 2   https://static.smallable.com/1731207-648x648q8...            New
# 3   https://static.smallable.com/1731362-648x648q8...            New
# 4   https://static.smallable.com/1731364-648x648q8...            New
# ..                                                ...            ...
# 21  https://static.smallable.com/1201445-648x648q8...
# 22  https://static.smallable.com/1204364-648x648q8...
# 23  https://static.smallable.com/1209522-648x648q8...      Promotion
# 24  https://static.smallable.com/1577392-648x648q8...      Promotion
# 25  https://static.smallable.com/1152707-648x648q8...      Promotion
#
#               brand                                      product_color
# 0   Deus Ex Machina                       Hoodie Venice Address | Grey  \
# 1            Komono                          Lionel Sunglasses | Green
# 2       Bobo Choses  Set 2 Paires Chaussettes - Collection Adulte  ...
# 3    The North Face                           Hoodie Essential | Black
# 4    The North Face                    Hoodie Essential | Heather grey
# ..              ...                                                ...
# 21           Komono       Sue Sunglasses - Adult Collection -   | Grey
# 22     Carhartt WIP                         Chase T-shirt  | Navy blue
# 23          Element                          Mohave Plain Bag  | Green
# 24         Toasties  Merino Wool Mittens - Adult Collection -  | Or...
# 25            K-way  Le Vrai 3.0 Claude Waterproof  Windcheater - W...
#
#                         price_euro
# 0                          €119.00
# 1                           €59.00
# 2                           €30.00
# 3                           €85.00
# 4                           €85.00
# ..                             ...
# 21                          €59.00
# 22                     From|€35.00
# 23              €32.00|€64.00|-50%
# 24   €87.50|€125.00|-30%|3 colours
# 25  €60.00|€120.00|-50%|11 colours
#
# [488 rows x 6 columns]
