# %% [markdown]
# # Web scraping to gather data: Women's New Collection

# %% [markdown]
# > - Using the smallable website, men's and women's products will be scraped to prepare for creating a clothing and accessories recommendation.

# %%
# try to webscrap smallable
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from time import sleep
import random

# %%
# women's new collection
w_new_pages = range(1,7)

# %%
w_new = f"https://www.smallable.com/en/fashion/adult/women?_collection=new-collection&_page="

# %%
# dataframe where all results will be stored
womens_new = pd.DataFrame()

# iteration for webscrapping multiple pages
for page in w_new_pages: #change pages on the link
    r = requests.get(f"https://www.smallable.com/en/fashion/adult/women?_collection=new-collection&_page={page}")
    print(f'Response for page {page} :', r.status_code)
    soup = BeautifulSoup(r.content, 'html.parser')
    
    #empty lists
    link = []
    img = []
    tags = []
    brand = []
    product_color = []
    price_euro = []

    #scrapping infos from site
    for i in soup.find_all('a', attrs={"class": "ProductCard_content__fBfLV"}):
        link.append(i.get("href")) #link to product
        img.append(i.select('img')[1].get("src")) # photo link
        tags.append(i.find("div", attrs = {"class" : "ProductTags_container__3cc_M"}).get_text(strip = True, separator = "|"))

    for i in soup.find_all('ul', attrs={"class": "ProductCard_attr__2e2YT"}):
        brand.append(i.select("li")[0].get_text(strip = True)) #brand name
        product_color.append(i.select("li")[1].get_text(strip = True)) #product | color
        price_euro.append(i.select("li")[2].get_text(strip = True, separator = "|")) #price
    
    new_df = pd.DataFrame(list(zip(link, img, tags, brand, product_color, price_euro)),columns=("link", "img", "tags", "brand", "product_color", "price_euro"))
    # store everything in the previously prepared df and concatenate new results from new webpages
    womens_new = pd.concat([womens_new, new_df])
    
    wait_time = random.randint(2,7)
    print("I will sleep for " + str(wait_time) + " seconds.")
    sleep(wait_time) #Script will be stopped for a period of time ranging from 2 to 7 seconds
# Out:
# Response for page 1 : 200
# I will sleep for 3 seconds.
# Response for page 2 : 200
# I will sleep for 7 seconds.
# Response for page 3 : 200
# I will sleep for 4 seconds.
# Response for page 4 : 200
# I will sleep for 4 seconds.
# Response for page 5 : 200
# I will sleep for 7 seconds.
# Response for page 6 : 200
# I will sleep for 7 seconds.

# %%
womens_new.to_csv('womens_new.csv', index=False)

# %%
womens_new.duplicated().sum()
# Out:
# 0

# %%
womens_new
# Out:
#                                                  link
# 0   /en/product/racine-earrings-gold-elise-tsikis-...  \
# 1          /en/product/bracelet-gold-5-octobre-228172
# 2   /en/product/tencel-lite-t-shirt-dusty-pink-org...
# 3    /en/product/amma-earrings-green-5-octobre-228168
# 4   /en/product/olympe-ring-gold-alix-d-reynis-227923
# ..                                                ...
# 32  /en/product/nina-long-dress-woman-collection-w...
# 33  /en/product/nina-long-dress-woman-collection-d...
# 34  /en/product/nina-long-dress-woman-collection-d...
# 35  /en/product/nina-long-dress-woman-collection-p...
# 36  /en/product/janis-sunglasses-adult-collection-...
#
#                                                   img           tags
# 0   https://static.smallable.com/1051694-648x648q8...      Promotion  \
# 1   https://static.smallable.com/1258753-648x648q8...            New
# 2   https://static.smallable.com/1217107-648x648q8...  New|Greenable
# 3   https://static.smallable.com/1258743-648x648q8...            New
# 4   https://static.smallable.com/1566300-648x648q8...      Promotion
# ..                                                ...            ...
# 32  https://static.smallable.com/997559-648x648q80...      Greenable
# 33  https://static.smallable.com/1000210-648x648q8...      Greenable
# 34  https://static.smallable.com/997547-648x648q80...      Greenable
# 35  https://static.smallable.com/1000300-648x648q8...      Greenable
# 36  https://static.smallable.com/1201478-648x648q8...
#
#              brand                                      product_color
# 0     Elise Tsikis                             Racine Earrings | Gold  \
# 1        5 Octobre                                    Bracelet | Gold
# 2   Organic Basics                  Tencel Lite T-Shirt  | Dusty Pink
# 3        5 Octobre                             Amma Earrings  | Green
# 4   Alix D. Reynis                                Olympe Ring  | Gold
# ..             ...                                                ...
# 32       Numero 74  Nina Long Dress  - Woman Collection  | White S001
# 33       Numero 74  Nina Long Dress  - Woman Collection  | Dusty P...
# 34       Numero 74  Nina Long Dress  - Woman Collection  | Dark Gr...
# 35       Numero 74  Nina Long Dress  - Woman Collection  | Powder ...
# 36          Komono     Janis Sunglasses - Adult Collection -   | Blue
#
#               price_euro
# 0   €164.50|€235.00|-30%
# 1                €110.00
# 2                 €55.00
# 3                €260.00
# 4    €90.00|€150.00|-40%
# ..                   ...
# 32      €85.00|7 colours
# 33      €85.00|7 colours
# 34      €85.00|7 colours
# 35      €85.00|7 colours
# 36                €59.00
#
# [247 rows x 6 columns]

# %%
# code adapted from Cormac and Isi
def request_link(link):
    try:
        request = requests.get(link)
        request.raise_for_status()  # returns an HTTPError if the response is not OK
        print("Success! Response code", request.status_code) 
    except requests.exceptions.HTTPError as err:
        if request.status_code == 404:
            print("404: Oops, sorry we can't find that page!")
        else:
            print("The error code is", err.args[0]) # look up the 1st argument from HTTPError 
    return request

# %%
w = request_link(w_new)
# Out:
# Success! Response code 200

# %%
soup = BeautifulSoup(w.content, "html.parser")

# %%
for item in soup.find_all('a', attrs={"class": "ProductCard_content__fBfLV"}):
        print(item.get("href")) #link to product
        print(item.select('img')[1].get("src")) # photo link
        print(item.find("div", attrs = {"class" : "ProductTags_container__3cc_M"}).get_text(strip = True, separator = "|"))
# Out:
# /en/product/racine-earrings-gold-elise-tsikis-169683
# https://static.smallable.com/1051694-648x648q80/racine-earrings.jpg
# Promotion
# /en/product/bracelet-gold-5-octobre-228172
# https://static.smallable.com/1258753-648x648q80/bracelet.jpg
# New
# /en/product/tencel-lite-t-shirt-dusty-pink-organic-basics-220748
# https://static.smallable.com/1217107-648x648q80/tencel-lite-t-shirt.jpg
# New|Greenable
# /en/product/amma-earrings-green-5-octobre-228168
# https://static.smallable.com/1258743-648x648q80/amma-earrings.jpg
# New
# /en/product/olympe-ring-gold-alix-d-reynis-227923
# https://static.smallable.com/1566300-648x648q80/olympe-ring.jpg
# Promotion
# /en/product/josephine-ring-blue-alix-d-reynis-227919
# https://static.smallable.com/1302898-648x648q80/josephine-ring.jpg
# Promotion
# /en/product/tencel-lite-bra-light-blue-organic-basics-209482
# https://static.smallable.com/1177538-648x648q80/tencel-lite-bra.jpg
# Promotion
# /en/product/shanga-necklace-white-soko-248333
# https://static.smallable.com/1692469-648x648q80/.jpg
# Promotion|Greenable
# /en/product/jamie-bikini-top-black-albertine-216364
# https://static.smallable.com/1686162-648x648q80/jamie-bikini-top.jpg
# Greenable
# /en/product/silk-eye-mask-mustard-nonchalance-248560
# https://static.smallable.com/1352351-648x648q80/.jpg
# Greenable
# /en/product/active-leggings-burgundy-organic-basics-239754
# https://static.smallable.com/1313628-648x648q80/.jpg
# Promotion|Greenable
# /en/product/felisia-jeans-navy-blue-made-in-tomboy-243104
# https://static.smallable.com/1294162-648x648q80/.jpg
# Sale
# /en/product/pomelo-trousers-women-s-collection-brown-poudre-organic-216152
# https://static.smallable.com/1239295-648x648q80/pomelo-trousers-women-s-collection-.jpg
# Greenable
# /en/product/camisa-organic-cotton-shirt-women-s-collection-black-poudre-organic-248303
# https://static.smallable.com/1339130-648x648q80/.jpg
# Greenable
# /en/product/longlivethequeen-x-smallable-collaboration-sweatshirt-women-s-collection-orange-longlivethequeen-224238
# https://static.smallable.com/1233670-648x648q80/longlivethequeen-x-smallable-collaboration-sweatshirt-women-s-collection-.jpg
# Exclusive|Greenable
# /en/product/brooklyn-shorts-mauve-cotton-citizen-234785
# https://static.smallable.com/1302777-648x648q80/.jpg
# Outlet
# /en/product/capilene-air-merino-wool-leggings-women-s-collection-black-patagonia-244733
# https://static.smallable.com/1314303-648x648q80/.jpg
# Promotion|Greenable
# /en/product/brooklyn-jogging-bottoms-fuchsia-cotton-citizen-234788
# https://static.smallable.com/1302779-648x648q80/.jpg
# Outlet
# /en/product/nikole-bracelet-gold-eliou-232304
# https://static.smallable.com/1256145-648x648q80/.jpg
# Sale
# /en/product/gourmette-bag-burgundy-lher-230551
# https://static.smallable.com/1260356-648x648q80/gourmette-bag.jpg
#
# /en/product/set-of-3-palmar-bracelets-white-eliou-232303
# https://static.smallable.com/1256143-648x648q80/.jpg
# Sale
# /en/product/frid-necklace-grey-bohemian-rhapsodie-259550
# https://static.smallable.com/1415027-648x648q80/.jpg
# Promotion
# /en/product/gilda-necklace-burgundy-bohemian-rhapsodie-259558
# https://static.smallable.com/1415051-648x648q80/.jpg
# Promotion
# /en/product/aleph-emerald-necklace-green-bohemian-rhapsodie-259563
# https://static.smallable.com/1415061-648x648q80/.jpg
#
# /en/product/aleph-ruby-necklace-burgundy-bohemian-rhapsodie-259560
# https://static.smallable.com/1415057-648x648q80/.jpg
#
# /en/product/ryder-ski-suit-black-perfect-moment-205921
# https://static.smallable.com/1186324-648x648q80/ryder-ski-suit.jpg
# Promotion
# /en/product/love-ceramic-bead-bracelet-bbuble-x-smallable-vanilla-bbuble-248685
# https://static.smallable.com/1392320-648x648q80/.jpg
# Sale
# /en/product/mum-ceramic-bead-bracelet-bbuble-x-smallable-ecru-bbuble-248686
# https://static.smallable.com/1392322-648x648q80/.jpg
# Sale
# /en/product/mama-ceramic-bead-bracelet-bbuble-x-smallable-terracotta-bbuble-248682
# https://static.smallable.com/1392314-648x648q80/.jpg
# Sale
# /en/product/boia-phone-leash-multicoloured-eliou-246883
# https://static.smallable.com/1322449-648x648q80/.jpg
# Sale
# /en/product/miley-phone-leash-multicoloured-eliou-246882
# https://static.smallable.com/1322448-648x648q80/.jpg
# Sale
# /en/product/eve-sunglasses-chain-multicoloured-eliou-246875
# https://static.smallable.com/1322434-648x648q80/.jpg
# Sale
# /en/product/latina-smoked-quartz-ring-gold-bonanza-249719
# https://static.smallable.com/1375146-648x648q80/.jpg
# Sale
# /en/product/mrs-ring-smoked-quartz-gold-bonanza-249717
# https://static.smallable.com/1375143-648x648q80/.jpg
# Sale
# /en/product/snowbelle-ski-jacket-women-s-collection-khaki-patagonia-244725
# https://static.smallable.com/1370997-648x648q80/.jpg
# Sale|Greenable
# /en/product/aleph-saphire-necklace-yellow-bohemian-rhapsodie-259562
# https://static.smallable.com/1373589-648x648q80/.jpg
#
# /en/product/oma-bracelet-white-eliou-246889
# https://static.smallable.com/1369420-648x648q80/.jpg
# Sale
# /en/product/styx-beanie-adult-collection-white-fusalp-205990
# https://static.smallable.com/1198215-648x648q80/styx-beanie-adult-collection.jpg
# Promotion
# /en/product/francoise-bracelet-gold-bonanza-228201
# https://static.smallable.com/1258605-648x648q80/francoise-bracelet.jpg
# Sale
# /en/product/happy-necklace-blue-lauren-rubinski-253392
# https://static.smallable.com/1365623-648x648q80/.jpg
# Sale
# /en/product/gourmette-two-tone-bag-camel-lher-230552
# https://static.smallable.com/1319279-648x648q80/gourmette-two-tone-bag.jpg
# Greenable
# /en/product/luck-bracelet-brown-lauren-rubinski-253391
# https://static.smallable.com/1365621-648x648q80/.jpg
# Sale

# %%
for i in soup.find_all('ul', attrs={"class": "ProductCard_attr__2e2YT"}):
        print(i.select("li")[0].get_text(strip = True)) #brand name
        print(i.select("li")[1].get_text(strip = True)) #product | color
        print(i.select("li")[2].get_text(strip = True, separator = "|")) #price
# Out:
# Elise Tsikis
# Racine Earrings | Gold
# €164.50|€235.00|-30%
# 5 Octobre
# Bracelet | Gold
# €110.00
# Organic Basics
# Tencel Lite T-Shirt  | Dusty Pink
# €55.00
# 5 Octobre
# Amma Earrings  | Green
# €260.00
# Alix D. Reynis
# Olympe Ring  | Gold
# €90.00|€150.00|-40%
# Alix D. Reynis
# Joséphine Ring  | Blue
# €119.00|€170.00|-30%
# Organic Basics
# Tencel Lite Bra  | Light blue
# €38.50|€55.00|-30%|5 colours
# Soko
# Shanga Necklace | White
# €58.10|€83.00|-30%
# Albertine
