# %% [markdown]
# # Create new category column (generalize categories taken from web scraping)

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import pandas as pd
import re
import numpy as np

# %% [markdown]
# ## LOAD DATA

# %%
all = pd.read_csv(r'./../data/cleaned_data/all_categories_unqiue.csv')

# %%
all.head()
# Out:
#                                                 link
# 0  /en/product/debardeur-namast-hey-white-yuj-331457  \
# 1   /en/product/tapis-chakra-power-purple-yuj-331460
# 2  /en/product/legging-manipura-marled-blue-yuj-3...
# 3  /en/product/brassiere-ajna-marled-blue-yuj-331458
# 4  /en/product/denize-bubble-crepe-dress-sand-bel...
#
#                                                  img
# 0  https://static.smallable.com/1730424-648x648q8...  \
# 1  https://static.smallable.com/1722207-648x648q8...
# 2  https://static.smallable.com/1722188-648x648q8...
# 3  https://static.smallable.com/1722184-648x648q8...
# 4  https://static.smallable.com/1686202-648x648q8...
#
#                      product        color       brand  greenable  discounted
# 0       debardeur namast'hey        white         yuj          1           0  \
# 1         tapis chakra power       purple         yuj          1           0
# 2           legging manipura  marled blue         yuj          1           0
# 3             brassiere ajna  marled blue         yuj          1           0
# 4  denize bubble crepe dress         sand  bellepiece          0           1
#
#    disc_price  orig_price collection        label gender
# 0        48.0        48.0         ss          top      w  \
# 1        79.0        79.0         ss  accessories      w
# 2        85.0        85.0         ss       bottom      w
# 3        59.0        59.0         ss    underwear      w
# 4       139.3       199.0         ss        dress      w
#
#            product_category
# 0                sports top
# 1                 yoga mats
# 2  sports leggings & shorts
# 3               sports bras
# 4              long dresses

# %% [markdown]
# ## PREPARING GENERALIZED LABELS

# %%
# check all categories taken from the website
all.product_category.unique()
# Out:
# array(['sports top', 'yoga mats', 'sports leggings & shorts',
#        'sports bras', 'long dresses', 'long sleeve shirts',
#        'short sleeve blouses', 'necklaces', 'straight leg trousers',
#        'shorts', 'caps', 'earrings', 'long skirts', 'shoulder bags',
#        'straight', 'short sleeve t-shirts', 'belts, braces',
#        'long sleeve blouses', 'handbags', 'bikini bottom', 'fanny packs',
#        'bikinis', 'small leather goods', 'bras', 'bracelets', 'jackets',
#        'hair clips', '1 piece swimsuits', 'pencil cases', 'pyjamas',
#        'rings', 'pouches', 'uv protective clothing', 'tank tops',
#        'tote bags', 'umbrellas', 'round neck jumpers',
#        'long sleeve t-shirts', 'sleeveless tops', 'hats', 'sunglasses',
#        'short dresses', 'short sleeve shirts', 'bikini top',
#        'toiletry bags, pouches', 'fleece sweatshirts', 'sets',
#        'round neck sweatshirts', 'jogging bottoms', 'jumpsuits',
#        'short skirts', 'beanies', 'capes, ponchos',
#        'skateboards, scooters & outdoor toys', 'playsuits', 'backpacks',
#        '/', 'slouchy trousers', 'bikini bottoms', 'kaftans and kimonos',
#        'flare, bootcut', 'denim skirts', 'watches', 'socks',
#        'v neck jumpers', 'menstrual swimwear', 'cardigans',
#        'cargo trousers', 'hooded sweatshirts', 'dungarees', 'bodysuit',
#        'velvet trousers', 'trench coats', 'sirwal trousers', 'coats',
#        'knickers', 'poloneck jumpers', 'sunhats', 'sports all-in-one',
#        'caps, beanies', 'foulards', 'tank tops, t-shirts',
#        'shorts, bermuda shorts', 'tapered', 'bags', 'fashion accessories',
#        'leggings, boxer shorts', 'slim trousers', 'scarves', 'waistcoats',
#        'culottes', 'dressing gowns', 'computer glasses',
#        'blouses, t-shirts', 'short sleeve polo shirts',
#        'zipped sweatshirts', 'raincoats', 'down jackets', 'slim, skinny',
#        'loose', 'parkas', 'toiletry bags', 'headbands',
#        'zip-neck jumpers', 'boyfriend', 'jewellery', 'gift pouch',
#        'nightdresses', 'gym bags', 'polo-neck jumpers', 'pants, jeans',
#        'robes', 'hoods', 'turtleneck jumpers', 'gloves', 'mittens',
#        'trousers, jeans, leggings, jogging bottoms',
#        'jumpers, waistcoats', 'sweatshirts', 'snoods',
#        'coat, down jacket, snowsuit', 'weekenders, tote bags',
#        'bloomers, shorts, skirts', 'baby grows, jumpsuits', 'dress',
#        'tights', 'fingerless gloves', 'cases, phone cases, sleeves',
#        't-shirts, shirts', 't-shirts, tops & blouses',
#        'briefs, swim shorts', 'boxers, briefs', 'long sleeve polo shirts',
#        'chinos', 'sweatshirts, sweaters', 'underwear', 'joggers'],
#       dtype=object)

# %%
# lists of keywords to look for in the product_category column to apply different labels
sports_accessories = [r"mat[s]{0,1}", r"sport[s]{0,1}"]
hair_accessories = [r"clip[s]{0,1}", r'headband[s]{0,1}']
wallets = [r"leather goods", r"case[s]{0,1}"]
pouches = [r"pouch[es]{0,1}", r'toilet[s]{0,1}',]
outdoor_toys = [r"skateboard[s]{0,1}", r"scooter[s]{0,1}"]
umbrellas = [r"umbrella[s]{0,1}"]

swimsuits = [r"bikini[s]{0,1}", r"swimsuit[s]{0,1}", r"uv", r"swim"]
underwears = [r"boxer[s]{0,1}", r"brief[s]{0,1}",  r"bra[s]{0,1}", r"knicker[s]{0,1}", r"culotte[s]{0,1}", r"tight[s]{0,1}", r"underwear[s]{0,1}"]
sleepwear = [r"pyjama[s]{0,1}", r"kimono[s]{0,1}", r"nightdress[es]{0,1}", r"gown[s]{0,1}", r"robe[s]{0,1}"]

tops = [r"top[s]{0,1}", r"blouse[s]{0,1}", r"[t-]{0,1}shirt[s]{0,1}"]
jumpers = [r"jumper[s]{0,1}", r"cardigan[s]{0,1}",  r"sweatshirt[s]{0,1}", r"sweater[s]{0,1}", r"pull[s]{0,1}", r"hood[s]{0,1}"]
bottoms = [r"bottom[s]{0,1}", r"trouser[s]{0,1}", r"legging[s]{0,1}", r"shorts", r"pant[s]{0,1}", r"jean[s]{0,1}", r'skirt[s]{0,1}', r'chino[s]{0,1}', r'flare[s]{0,1}', r'slim[s]{0,1}', r'loose[s]{0,1}', r'tapered', r'bottom[s]{0,1}', r"jogger[s]{0,1}", r'straight[s]{0,1}', r"boyfriend[s]{0,1}"]
dress_overalls = [r"dress[es]{0,1}", r"dungaree[s]{0,1}", r"bodysuit[s]{0,1}", r"playsuit[s]{0,1}", r"set[s]{0,1}", r"jumpsuit[s]{0,1}"]
coats = [r"capes", r"ponchos", r"coat[s]{0,1}", r"jacket[s]{0,1}", r"parka[s]{0,1}"]

jewelries = [r'necklace[s]{0,1}', r"earring[s]{0,1}", r"bracelet[s]{0,1}", r"ring[s]{0,1}", r"watch[es]{0,1}", r"jewellery"]
accessories = [r"caps", r"[sun]{0,1}hat[s]{0,1}", r"beanie[s]{0,1}", r"belt[s]{0,1}", r"[sun]{0,1}glass[es]{0,1}", r"scarf", r"scarves", r"accessories", r"foulard[s]{0,1}", r"snood[s]{0,1}", r"glove[s]{0,1}", r"mitten[s]{0,1}", r"sock[s]{0,1}"]
bags = [r"bag[s]{0,1}", r"[back]{0,1}pack[s]{0,1}"]

# %% [markdown]
# > **NOTE: Although everything is being marked for their categories, we will only keep products with the following results:**
# > | category     |label|
# > |----------------|-----|
# > | accessories    | 0 |
# > | bag            | 1 |
# > | bottom         | 2 |
# > | coat           | 3 |
# > | dress_overalls | 4 |
# > | jewelry        | 5 |
# > | jumper         | 6 |
# > | top            | 7 |

# %%
# function to extract labels
def extract_label(df):
    """This function will use the lists provided above to extract the category of a product using the product column of the dataframe.
    Depending on the percentage of the data lost during the process, we will either review the list or proceed with the dataset acquired."""
    
    categories = [sports_accessories, hair_accessories, wallets,  pouches, outdoor_toys, umbrellas, swimsuits, underwears, sleepwear, 
                accessories, dress_overalls, bottoms, jewelries, jumpers, tops,  coats, bags]
    labels = ["sportswear", "hair_accessories", "wallet", "pouch", "scooter", "umbrella", "swimwear", "underwear", "sleepwear", 
              "accessories", "dress_overalls", "bottom", "jewelry", "jumper", "top", "coat", "bag"]
    
    # empty lists to store the data
    index = []
    category = []
    
    for ind in df.index:
        found=False
        for c, l in zip(categories, labels):
            for r in c:
                if re.search(r, df.product_category[ind]):
                    index.append(ind)
                    category.append(l)
                    found = True 
                    break # move on to the next row and avoid duplicates
                
                elif re.search(r, df['product'][ind]):
                    index.append(ind)
                    category.append(l)
                    found = True 
                    break # move on to the next row and avoid duplicates
                        
            if found: # check if flag is True
                break
            
        if not found:
            index.append(ind)
            category.append(np.nan) # fill missing labels with NaN

    # Create new label column 
    new_df = pd.DataFrame(category, index=index, columns=['category'])
    df_add = pd.concat([df, new_df], axis=1)
    missing = df_add[df_add.category.isna()==True]
    print(round((len(missing)/len(df))*100, 2), "% missing labels :",len(missing))
    
    return new_df, df_add, missing

# %%
new_df, all1, missing = extract_label(all)
# Out:
# 0.33 % missing labels : 27

# %%
missing
# Out:
#                                                    link
# 712   /en/product/menstrual-tanga-antheia-light-flow...  \
# 713   /en/product/menstrual-thong-antheia-light-flow...
# 1121        /en/product/scrunchie-lilac-bond-eye-301484
# 1627  /en/product/menstrual-feel-thong-light-flow-bl...
# 1682  /en/product/menstrual-feel-thong-light-flow-pi...
# 2256     /en/product/sirocco-fan-black-lastelier-274888
# 2258     /en/product/sirocco-fan-brown-lastelier-274886
# 2327  /en/product/akimmi-scrunchie-blue-louise-misha...
# 2689  /en/product/scrunchie-grass-green-bond-eye-301483
# 2726  /en/product/scrunchie-navy-blue-call-it-by-you...
# 3164  /en/product/terry-wave-scrunchie-orange-aramin...
# 3317  /en/product/cat-sun-snow-ski-mask-adult-collec...
# 3326  /en/product/sun-snow-ski-mask-adult-collection...
# 3763  /en/product/terry-scrunchie-pink-araminta-jame...
# 3773  /en/product/terry-wave-scrunchie-light-blue-ar...
# 4809  /en/product/terry-cloth-scrunchie-exclusive-ar...
# 4811  /en/product/scrunchie-plum-girlfriend-collecti...
# 5093  /en/product/chouchou-khaalia-collection-femme-...
# 5095  /en/product/chouchou-khaalia-collection-femme-...
# 5142  /en/product/chouchou-gingham-brown-beck-sonder...
# 5143  /en/product/chouchou-penfold-navy-blue-beck-so...
# 5835  /en/product/limone-scrunchie-ecru-beck-sonder-...
# 5944  /en/product/limone-scrunchie-black-beck-sonder...
# 6178   /en/product/mama-phone-strap-cream-bbuble-298244
# 6179   /en/product/love-phone-strap-cream-bbuble-298243
# 6845  /en/product/boia-phone-leash-multicoloured-eli...
# 6846  /en/product/miley-phone-leash-multicoloured-el...
#
#                                                     img
# 712   https://static.smallable.com/1666374-648x648q8...  \
# 713   https://static.smallable.com/1666367-648x648q8...
# 1121  https://static.smallable.com/1616781-648x648q8...
# 1627  https://static.smallable.com/1628209-648x648q8...
# 1682  https://static.smallable.com/1628212-648x648q8...
# 2256  https://static.smallable.com/1439264-648x648q8...
# 2258  https://static.smallable.com/1439249-648x648q8...
# 2327  https://static.smallable.com/1601432-648x648q8...
# 2689  https://static.smallable.com/1616779-648x648q8...
# 2726  https://static.smallable.com/1380518-648x648q8...
# 3164  https://static.smallable.com/1577650-648x648q8...
# 3317  https://static.smallable.com/1591165-648x648q8...
# 3326  https://static.smallable.com/1591676-648x648q8...
# 3763  https://static.smallable.com/1577646-648x648q8...
# 3773  https://static.smallable.com/1577648-648x648q8...
# 4809  https://static.smallable.com/1349070-648x648q8...
# 4811  https://static.smallable.com/1237831-648x648q8...
# 5093  https://static.smallable.com/1721952-648x648q8...
# 5095  https://static.smallable.com/1721946-648x648q8...
# 5142  https://static.smallable.com/1710270-648x648q8...
# 5143  https://static.smallable.com/1710271-648x648q8...
# 5835  https://static.smallable.com/1688707-648x648q8...
# 5944  https://static.smallable.com/1678451-648x648q8...
# 6178  https://static.smallable.com/1565348-648x648q8...
# 6179  https://static.smallable.com/1565347-648x648q8...
# 6845  https://static.smallable.com/1322449-648x648q8...
# 6846  https://static.smallable.com/1322448-648x648q8...
#
#                                                 product          color
# 712                menstrual tanga antheia - light flow          black  \
# 713                menstrual thong antheia - light flow          black
# 1121                                         scrunchie           lilac
# 1627                  menstrual feel thong - light flow          black
# 1682                  menstrual feel thong - light flow           pink
# 2256                                        sirocco fan          black
# 2258                                        sirocco fan          brown
# 2327                                   akimmi scrunchie           blue
# 2689                                         scrunchie     grass green
# 2726                                          scrunchie      navy blue
# 3164                               terry wave scrunchie         orange
# 3317           cat sun snow ski mask - adult collection          black
# 3326               sun snow ski mask - adult collection         orange
# 3763                                    terry scrunchie           pink
# 3773                               terry wave scrunchie     light blue
# 4809  terry cloth scrunchie - exclusive araminta jam...     light blue
# 4811                                          scrunchie           plum
# 5093               chouchou khaalia - collection femme            rust
# 5095               chouchou khaalia - collection femme   midnight blue
# 5142                                   chouchou gingham          brown
# 5143                                   chouchou penfold      navy blue
# 5835                                   limone scrunchie           ecru
# 5944                                   limone scrunchie          black
# 6178                                   mama phone strap          cream
# 6179                                   love phone strap          cream
# 6845                                   boia phone leash  multicoloured
# 6846                                  miley phone leash  multicoloured
#
#                       brand  greenable  discounted  disc_price  orig_price
# 712                réjeanne          1           0        39.0        39.0  \
# 713                réjeanne          1           0        39.0        39.0
# 1121               bond-eye          1           0        35.0        35.0
# 1627                 pantys          1           0        32.0        32.0
# 1682                 pantys          1           0        32.0        32.0
# 2256              lastelier          1           0       105.0       105.0
# 2258              lastelier          1           0       105.0       105.0
# 2327           louise misha          0           1        10.2        17.0
# 2689               bond-eye          1           0        35.0        35.0
# 2726   call it by your name          1           0        15.0        15.0
# 3164         araminta james          0           1        17.4        29.0
# 3317                izipizi          0           0        80.0        80.0
# 3326                izipizi          0           0        80.0        80.0
# 3763         araminta james          0           1        17.4        29.0
# 3773         araminta james          0           1        17.4        29.0
# 4809         araminta james          0           1        14.7        21.0
# 4811  girlfriend collective          1           0         8.0         8.0
# 5093           louise misha          0           0        15.0        15.0
# 5095           louise misha          0           0        15.0        15.0
# 5142        becksöndergaard          0           0        11.0        11.0
# 5143        becksöndergaard          0           0        11.0        11.0
# 5835        becksöndergaard          0           0         9.0         9.0
# 5944        becksöndergaard          0           0         9.0         9.0
# 6178                 bbuble          1           1        31.5        45.0
# 6179                 bbuble          1           1        31.5        45.0
# 6845                  eliou          0           1        73.2       122.0
# 6846                  eliou          0           1        68.4       114.0
#
#      collection           label gender product_category category
# 712          ss       underwear      w                /      NaN
# 713          ss       underwear      w                /      NaN
# 1121         ss  hair_accessory      w                /      NaN
# 1627         ss       underwear      w                /      NaN
# 1682         ss       underwear      w                /      NaN
# 2256         ss     accessories      w                /      NaN
# 2258         ss     accessories      w                /      NaN
# 2327         ss  hair_accessory      w                /      NaN
# 2689         ss  hair_accessory      w                /      NaN
# 2726         ss  hair_accessory      w                /      NaN
# 3164         ss  hair_accessory      w                /      NaN
# 3317         ss       sleepwear      w                /      NaN
# 3326         ss       sleepwear      w                /      NaN
# 3763         ss  hair_accessory      w                /      NaN
# 3773         ss  hair_accessory      w                /      NaN
# 4809         ss  hair_accessory      w                /      NaN
# 4811         ss  hair_accessory      w                /      NaN
# 5093         fw  hair_accessory      w                /      NaN
# 5095         fw  hair_accessory      w                /      NaN
# 5142         fw  hair_accessory      w                /      NaN
# 5143         fw  hair_accessory      w                /      NaN
# 5835         fw  hair_accessory      w                /      NaN
# 5944         fw  hair_accessory      w                /      NaN
# 6178         fw         jewelry      w                /      NaN
# 6179         fw         jewelry      w                /      NaN
# 6845         fw         jewelry      w                /      NaN
# 6846         fw         jewelry      w                /      NaN

# %% [markdown]
# > **NOTE:** Since the number of missing values is minimal and most of them are not in the categories we wish to keep for the recommender, we will opt to drop them.

# %%
all2 = all1.dropna().reset_index(drop=True)

# %%
# save to csv
all2.to_csv('all_labelled_complete.csv', index=False)

# %%
# list of categories to keep
categories_to_keep = ["jumper", "top", "bottom", "dress_overalls", "coat", "jewelry", "accessories", "bag"]

# %%
# new df to take only items in the categories above
all_filtered = all2[all2['category'].isin(categories_to_keep)]

# %%
# double-checking unique values in the category column
all_filtered.category.unique() # seems to be in order
# Out:
# array(['dress_overalls', 'top', 'jewelry', 'bottom', 'accessories', 'bag',
#        'coat', 'jumper'], dtype=object)

# %%
all_filtered.category.value_counts()
# Out:
# category
# top               1447
# bottom             983
# accessories        764
# dress_overalls     643
# jumper             601
# bag                548
# jewelry            547
# coat               345
# Name: count, dtype: int64

# %%
# reset index
all_filtered.reset_index(drop=True, inplace=True)

# %%
all_filtered.head()
# Out:
#                                                 link
# 0  /en/product/denize-bubble-crepe-dress-sand-bel...  \
# 1  /en/product/cabane-printed-shirt-blue-hartford...
# 2  /en/product/garden-striped-cotton-poplin-top-b...
# 3  /en/product/tsikis-x-alma-deia-exclusive-blava...
# 4  /en/product/peggy-ibiza-striped-dress-yellow-t...
#
#                                                  img
# 0  https://static.smallable.com/1686202-648x648q8...  \
# 1  https://static.smallable.com/1588974-648x648q8...
# 2  https://static.smallable.com/1677878-648x648q8...
# 3  https://static.smallable.com/1641315-648x648q8...
# 4  https://static.smallable.com/1669582-648x648q8...
#
#                                            product   color              brand
# 0                        denize bubble crepe dress    sand         bellepiece  \
# 1                             cabane printed shirt    blue           hartford
# 2                 garden striped cotton poplin top    blue      girls of dust
# 3  tsikis x alma deia exclusive - blava body chain  orange          alma deia
# 4                        peggy ibiza striped dress  yellow  the label edition
#
#    greenable  discounted  disc_price  orig_price collection      label gender
# 0          0           1       139.3       199.0         ss      dress      w  \
# 1          0           0       155.0       155.0         ss        top      w
# 2          0           1       108.0       135.0         ss        top      w
# 3          0           0       215.0       215.0         ss  underwear      w
# 4          0           1       308.0       440.0         ss      dress      w
#
#        product_category        category
# 0          long dresses  dress_overalls
# 1    long sleeve shirts             top
# 2  short sleeve blouses             top
# 3             necklaces         jewelry
# 4          long dresses  dress_overalls

# %%
# save to csv
all_filtered.to_csv('filtered_all.csv', index=False)

# %%
all_filtered.iloc[2199]
# Out:
# link                /en/product/solid-rain-cape-lavender-beck-sond...
# img                 https://static.smallable.com/1604505-648x648q8...
# product                                               solid rain cape
# color                                                        lavender
# brand                                                 becksöndergaard
# greenable                                                           0
# discounted                                                          1
# disc_price                                                       50.0
# orig_price                                                      100.0
# collection                                                         ss
# label                                                            coat
# gender                                                              w
# product_category                                       capes, ponchos
# category                                                         coat
# Name: 2199, dtype: object

# %%
all_filtered.iloc[4979]
# Out:
# link                /en/product/t-shirt-homme-coton-bio-dusty-pink...
# img                 https://static.smallable.com/1697376-648x648q8...
# product                                       t-shirt homme coton bio
# color                                                      dusty pink
# brand                                                smallable basics
# greenable                                                           1
# discounted                                                          0
# disc_price                                                       45.0
# orig_price                                                       45.0
# collection                                                         ss
# label                                                             top
# gender                                                              m
# product_category                                short sleeve t-shirts
# category                                                          top
# Name: 4979, dtype: object
